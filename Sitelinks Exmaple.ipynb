# %%
import pandas
import math
import json
from numpy.random import *
from matplotlib import style
style.use('fivethirtyeight')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'power', 'bytes']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
sitelinks = pandas.read_csv('snapshot_data/2014-10-13/property_indexes/site_linkss-index.csv',index_col=0).fillna(0)

# %%
sitelinks.head()
# Out:
#               nan  transgender female  intersex  fa'afafine  transgender male  \
# NaN          4172                   0         0           0                 0
# abwiki          0                   0         0           0                 0
# acewiki         4                   0         0           0                 0
# afwiki        186                   0         0           0                 0
# afwikiquote     1                   0         0           0                 0
#
#              female animal  male animal  woman  genderqueer  female   male  \
# NaN                      0            0      0            0    4027  16255
# abwiki                   0            0      0            0      12    104
# acewiki                  0            0      0            0      52    200
# afwiki                   0            0      0            0     570   4223
# afwikiquote              0            0      0            0       5    103
#
#              kathoey
# NaN                0
# abwiki             0
# acewiki            0
# afwiki             0
# afwikiquote        0

# %% [markdown]
# The Wikidata Items that have no sitelinks

# %% [markdown]
# This means there are 24,454 humans in Wikidata not connected not in any other Wiki. We don't know the gender for 4,172. 4,027 of them are female, and 16,255 of them are male.

# %% [markdown]
# Now we will look at the wikis which have the most and least gender recordings for their human data

# %%
sitelinks['human_total'] = sitelinks.sum(axis=1)
sitelinks['gendered_total'] = sitelinks['human_total'] - sitelinks['nan']
sitelinks['gendered_per'] = sitelinks['gendered_total'] / sitelinks['human_total']
sitelinks['nonbin_total'] = sitelinks['gendered_total'] - sitelinks['female'] - sitelinks['male']

# %%
sitelinks[sitelinks['human_total'] > 10000].sort('gendered_per').head()
# Out:
#            nan  transgender female  intersex  fa'afafine  transgender male  \
# jawiki  103079                  17         1           1                 0
# zhwiki   53542                  13         0           1                 1
# azwiki    5512                   1         0           0                 0
# ltwiki    7383                   0         0           0                 0
# kowiki   14052                  20         1           0                 2
#
#         female animal  male animal  woman  genderqueer  female    male  \
# jawiki              0            0      0            1   35393  102361
# zhwiki              0            0      0            0   17550   55149
# azwiki              0            0      0            0    1509    8475
# ltwiki              0            0      0            0    2502   16527
# kowiki              0            0      0            2    9233   34233
#
#         kathoey  human_total  gendered_total  gendered_per  nonbin_total
# jawiki        1       240854          137775      0.572027            21
# zhwiki        1       126257           72715      0.575928            16
# azwiki        0        15497            9985      0.644318             1
# ltwiki        0        26412           19029      0.720468             0
# kowiki        1        57544           43492      0.755804            26

# %%
sitelinks[sitelinks !=  0]
# Out:
#                        nan  transgender female  intersex  fa'afafine  \
# NaN                   4172                 NaN       NaN         NaN
# abwiki                 NaN                 NaN       NaN         NaN
# acewiki                  4                 NaN       NaN         NaN
# afwiki                 186                 NaN       NaN         NaN
# afwikiquote              1                 NaN       NaN         NaN
# akwiki                 NaN                 NaN       NaN         NaN
# alswiki                 13                 NaN       NaN         NaN
# amwiki                   2                 NaN       NaN         NaN
# angwiki                NaN                 NaN       NaN         NaN
# angwikiquote           NaN                 NaN       NaN         NaN
# anwiki                  16                 NaN       NaN         NaN
# arcwiki                  1                 NaN       NaN         NaN
# arwiki                2537                   3       NaN         NaN
# arwikinews             NaN                 NaN       NaN         NaN
# arwikiquote            NaN                 NaN       NaN         NaN
# arwikisource           NaN                 NaN       NaN         NaN
# arzwiki                167                   1       NaN         NaN
# astwiki                 15                 NaN       NaN         NaN
# aswiki                   2                 NaN       NaN         NaN
# avwiki                   1                 NaN       NaN         NaN
# aywiki                   1                 NaN       NaN         NaN
# azwiki                5512                   1       NaN         NaN
# azwikiquote             12                 NaN       NaN         NaN
# azwikisource           NaN                 NaN       NaN         NaN
# barwiki                  2                 NaN       NaN         NaN
# bat_smgwiki             60                 NaN       NaN         NaN
# bawiki                 NaN                 NaN       NaN         NaN
# bclwiki                  2                 NaN       NaN         NaN
# be_x_oldwiki           228                   1       NaN         NaN
# bewiki                 617                   1       NaN         NaN
# ...                    ...                 ...       ...         ...
# vecwikisource           55                 NaN       NaN         NaN
# vepwiki                  4                 NaN       NaN         NaN
# vewiki                 NaN                 NaN       NaN         NaN
# viwiki                4635                   3       NaN         NaN
# viwikiquote              1                 NaN       NaN         NaN
# viwikisource             3                 NaN       NaN         NaN
# vlswiki                  5                 NaN       NaN         NaN
# vowiki                  35                 NaN       NaN         NaN
# warwiki                  3                 NaN       NaN         NaN
# wawiki                   3                 NaN       NaN         NaN
# wikidatawiki           NaN                 NaN       NaN         NaN
# wowiki                   1                 NaN       NaN         NaN
# wowikiquote            NaN                 NaN       NaN         NaN
# wuuwiki                 33                 NaN       NaN         NaN
# xalwiki                NaN                 NaN       NaN         NaN
# xhwiki                   1                 NaN       NaN         NaN
# xmfwiki                  2                 NaN       NaN         NaN
# yiwiki                   5                 NaN       NaN         NaN
# yowiki                   6                 NaN       NaN         NaN
# zawiki                   3                 NaN       NaN         NaN
# zeawiki                  2                 NaN       NaN         NaN
# zh_classicalwiki       153                 NaN       NaN         NaN
# zh_min_nanwiki          79                   1       NaN         NaN
# zh_min_nanwikiquote    NaN                 NaN       NaN         NaN
# zh_yuewiki             311                   3       NaN         NaN
# zhwiki               53542                  13       NaN           1
# zhwikinews             NaN                 NaN       NaN         NaN
# zhwikiquote             16                 NaN       NaN         NaN
# zhwikisource            40                 NaN       NaN         NaN
# zuwiki                   2                 NaN       NaN         NaN
#
#                      transgender male  female animal  male animal  woman  \
# NaN                               NaN            NaN          NaN    NaN
# abwiki                            NaN            NaN          NaN    NaN
# acewiki                           NaN            NaN          NaN    NaN
# afwiki                            NaN            NaN          NaN    NaN
# afwikiquote                       NaN            NaN          NaN    NaN
# akwiki                            NaN            NaN          NaN    NaN
# alswiki                           NaN            NaN          NaN    NaN
# amwiki                            NaN            NaN          NaN    NaN
# angwiki                           NaN            NaN          NaN    NaN
# angwikiquote                      NaN            NaN          NaN    NaN
# anwiki                            NaN            NaN          NaN    NaN
# arcwiki                           NaN            NaN          NaN    NaN
# arwiki                            NaN            NaN          NaN    NaN
# arwikinews                        NaN            NaN          NaN    NaN
# arwikiquote                       NaN            NaN          NaN    NaN
# arwikisource                      NaN            NaN          NaN    NaN
# arzwiki                             1            NaN          NaN    NaN
# astwiki                           NaN            NaN          NaN    NaN
# aswiki                            NaN            NaN          NaN    NaN
# avwiki                            NaN            NaN          NaN    NaN
# aywiki                            NaN            NaN          NaN    NaN
# azwiki                            NaN            NaN          NaN    NaN
# azwikiquote                       NaN            NaN          NaN    NaN
# azwikisource                      NaN            NaN          NaN    NaN
# barwiki                           NaN            NaN          NaN    NaN
# bat_smgwiki                       NaN            NaN          NaN    NaN
# bawiki                            NaN            NaN          NaN    NaN
# bclwiki                           NaN            NaN          NaN    NaN
# be_x_oldwiki                      NaN            NaN          NaN    NaN
# bewiki                            NaN            NaN          NaN    NaN
# ...                               ...            ...          ...    ...
# vecwikisource                     NaN            NaN          NaN    NaN
# vepwiki                           NaN            NaN          NaN    NaN
# vewiki                            NaN            NaN          NaN    NaN
# viwiki                            NaN            NaN          NaN    NaN
# viwikiquote                       NaN            NaN          NaN    NaN
# viwikisource                      NaN            NaN          NaN    NaN
# vlswiki                           NaN            NaN          NaN    NaN
# vowiki                            NaN            NaN          NaN    NaN
# warwiki                           NaN            NaN          NaN    NaN
# wawiki                            NaN            NaN          NaN    NaN
# wikidatawiki                      NaN            NaN          NaN    NaN
# wowiki                            NaN            NaN          NaN    NaN
# wowikiquote                       NaN            NaN          NaN    NaN
# wuuwiki                           NaN            NaN          NaN    NaN
# xalwiki                           NaN            NaN          NaN    NaN
# xhwiki                            NaN            NaN          NaN    NaN
# xmfwiki                           NaN            NaN          NaN    NaN
# yiwiki                            NaN            NaN          NaN    NaN
# yowiki                            NaN            NaN          NaN    NaN
# zawiki                            NaN            NaN          NaN    NaN
# zeawiki                           NaN            NaN          NaN    NaN
# zh_classicalwiki                  NaN            NaN          NaN    NaN
# zh_min_nanwiki                    NaN            NaN          NaN    NaN
# zh_min_nanwikiquote               NaN            NaN          NaN    NaN
# zh_yuewiki                        NaN            NaN          NaN    NaN
# zhwiki                              1            NaN          NaN    NaN
# zhwikinews                        NaN            NaN          NaN    NaN
# zhwikiquote                       NaN            NaN          NaN    NaN
# zhwikisource                      NaN            NaN          NaN    NaN
# zuwiki                            NaN            NaN          NaN    NaN
#
#                      genderqueer  female   male  kathoey  human_total  \
# NaN                          NaN    4027  16255      NaN        24454
# abwiki                       NaN      12    104      NaN          116
# acewiki                      NaN      52    200      NaN          256
# afwiki                       NaN     570   4223      NaN         4979
# afwikiquote                  NaN       5    103      NaN          109
# akwiki                       NaN       3     21      NaN           24
# alswiki                      NaN     241   1973      NaN         2227
# amwiki                       NaN      85    773      NaN          860
# angwiki                      NaN      59    224      NaN          283
# angwikiquote                 NaN     NaN      3      NaN            3
# anwiki                       NaN     656   3555      NaN         4227
# arcwiki                      NaN      13    125      NaN          139
# arwiki                       NaN    6069  37904      NaN        46513
# arwikinews                   NaN       1     10      NaN           11
# arwikiquote                  NaN      13    164      NaN          177
# arwikisource                 NaN       2     24      NaN           26
# arzwiki                      NaN    1223   2566      NaN         3958
# astwiki                      NaN     319   1862      NaN         2196
# aswiki                       NaN      74    388      NaN          464
# avwiki                       NaN     NaN     45      NaN           46
# aywiki                       NaN      21    258      NaN          280
# azwiki                       NaN    1509   8475      NaN        15497
# azwikiquote                  NaN      33    550      NaN          595
# azwikisource                 NaN     NaN     13      NaN           13
# barwiki                      NaN     155   1058      NaN         1215
# bat_smgwiki                  NaN     145    751      NaN          956
# bawiki                       NaN      76    625      NaN          701
# bclwiki                      NaN      95    494      NaN          591
# be_x_oldwiki                 NaN     930   7808      NaN         8967
# bewiki                       NaN    1808  14848      NaN        17274
# ...                          ...     ...    ...      ...          ...
# vecwikisource                NaN       1     75      NaN          131
# vepwiki                      NaN     103    326      NaN          433
# vewiki                       NaN       2      3      NaN            5
# viwiki                       NaN    3147  14544      NaN        22329
# viwikiquote                  NaN      14     72      NaN           87
# viwikisource                 NaN       2     44      NaN           49
# vlswiki                      NaN     135    730      NaN          870
# vowiki                       NaN      70    595      NaN          700
# warwiki                      NaN     311   2394      NaN         2708
# wawiki                       NaN     103    818      NaN          924
# wikidatawiki                 NaN     NaN      1      NaN            1
# wowiki                       NaN       9     68      NaN           78
# wowikiquote                  NaN       2      7      NaN            9
# wuuwiki                      NaN     167    307      NaN          507
# xalwiki                      NaN       2     56      NaN           58
# xhwiki                       NaN       6     32      NaN           39
# xmfwiki                      NaN      66    543      NaN          611
# yiwiki                       NaN     157   1740      NaN         1902
# yowiki                       NaN     686   5953      NaN         6645
# zawiki                       NaN       4     94      NaN          101
# zeawiki                      NaN      56    162      NaN          220
# zh_classicalwiki             NaN      64    834      NaN         1051
# zh_min_nanwiki               NaN     402   1345      NaN         1827
# zh_min_nanwikiquote          NaN     NaN      6      NaN            6
# zh_yuewiki                   NaN     830   2429      NaN         3573
# zhwiki                       NaN   17550  55149        1       126257
# zhwikinews                   NaN       1      3      NaN            4
# zhwikiquote                  NaN      70    571      NaN          657
# zhwikisource                 NaN      17    227      NaN          284
# zuwiki                       NaN      47     97      NaN          146
#
#                      gendered_total  gendered_per  nonbin_total
# NaN                           20282      0.829394           NaN
# abwiki                          116      1.000000           NaN
# acewiki                         252      0.984375           NaN
# afwiki                         4793      0.962643           NaN
# afwikiquote                     108      0.990826           NaN
# akwiki                           24      1.000000           NaN
# alswiki                        2214      0.994163           NaN
# amwiki                          858      0.997674           NaN
# angwiki                         283      1.000000           NaN
# angwikiquote                      3      1.000000           NaN
# anwiki                         4211      0.996215           NaN
# arcwiki                         138      0.992806           NaN
# arwiki                        43976      0.945456             3
# arwikinews                       11      1.000000           NaN
# arwikiquote                     177      1.000000           NaN
# arwikisource                     26      1.000000           NaN
# arzwiki                        3791      0.957807             2
# astwiki                        2181      0.993169           NaN
# aswiki                          462      0.995690           NaN
# avwiki                           45      0.978261           NaN
# aywiki                          279      0.996429           NaN
# azwiki                         9985      0.644318             1
# azwikiquote                     583      0.979832           NaN
# azwikisource                     13      1.000000           NaN
# barwiki                        1213      0.998354           NaN
# bat_smgwiki                     896      0.937238           NaN
# bawiki                          701      1.000000           NaN
# bclwiki                         589      0.996616           NaN
# be_x_oldwiki                   8739      0.974573             1
# bewiki                        16657      0.964282             1
# ...                             ...           ...           ...
# vecwikisource                    76      0.580153           NaN
# vepwiki                         429      0.990762           NaN
# vewiki                            5      1.000000           NaN
# viwiki                        17694      0.792422             3
# viwikiquote                      86      0.988506           NaN
# viwikisource                     46      0.938776           NaN
# vlswiki                         865      0.994253           NaN
# vowiki                          665      0.950000           NaN
# warwiki                        2705      0.998892           NaN
# wawiki                          921      0.996753           NaN
# wikidatawiki                      1      1.000000           NaN
# wowiki                           77      0.987179           NaN
# wowikiquote                       9      1.000000           NaN
# wuuwiki                         474      0.934911           NaN
# xalwiki                          58      1.000000           NaN
# xhwiki                           38      0.974359           NaN
# xmfwiki                         609      0.996727           NaN
# yiwiki                         1897      0.997371           NaN
# yowiki                         6639      0.999097           NaN
# zawiki                           98      0.970297           NaN
# zeawiki                         218      0.990909           NaN
# zh_classicalwiki                898      0.854424           NaN
# zh_min_nanwiki                 1748      0.956760             1
# zh_min_nanwikiquote               6      1.000000           NaN
# zh_yuewiki                     3262      0.912958             3
# zhwiki                        72715      0.575928            16
# zhwikinews                        4      1.000000           NaN
# zhwikiquote                     641      0.975647           NaN
# zhwikisource                    244      0.859155           NaN
# zuwiki                          144      0.986301           NaN
#
# [428 rows x 16 columns]

# %%
sitelinks.drop(float('nan'), inplace=True)

# %%
suffixes = set()

for bits in map(lambda x: x.split('wiki'), sitelinks.index):
    if len(bits) == 3:
        continue
    else:
        pre = bits[0]
        suff = bits[1]
        suffixes.add(suff)

# %%
suffixes
# Out:
# {'', 'news', 'quote', 'source', 'voyage'}

# %%
def wikityper(wikiname):
    suff = wikiname.split('wiki')[1]
    return 'pedia' if suff == '' else suff

def wikilanger(wikiname):
    pre = wikiname.split('wiki')[0]
    return pre if pre else None
    
sitelinks['wikitype'] = map(wikityper, sitelinks.index)
sitelinks['wikilang'] = map(wikilanger, sitelinks.index)
sitelinks['fem_per'] = sitelinks['female'] / sitelinks['gendered_total']
sitelinks['nonbin_per'] = sitelinks['nonbin_total'] / sitelinks['gendered_total']

# %%
wikitypes = sitelinks.groupby(by='wikitype')

# %%
wikitypes.mean()[['female','male','fem_per','nonbin_per','gendered_total']]
# Out:
#                female          male   fem_per  nonbin_per  gendered_total
# wikitype
# data         0.000000      1.000000  0.000000    0.000000        1.000000
# news         6.807692     27.923077  0.128818    0.000000       34.730769
# pedia     3185.471223  16748.082734  0.162319    0.000176    19936.219424
# quote      121.641791    845.567164  0.085339    0.000073      967.343284
# source      50.660377    690.528302  0.047709    0.000000      741.188679
# voyage       0.000000      4.500000  0.000000    0.000000        4.500000

# %% [markdown]
# So this means that the female percentage is actually highest on Wikipedias in general at 16% where as for Wikiquote and Wikisource its only 8.5% and 4.7% respectively.

# %%
lang_map = json.load(open('helpers/wiki_code_map.json','r'))
def lookup_lang(lang):
    try:
            full= lang_map[lang]
            if full.split()[-1].lower() == 'wikipedia':
                return ' '.join(full.split()[:-1])
            else: return full
    except:
        return lang

# %%
splitpoints = 5

for sort_term, sort_term_text in [('gendered_total', 'number of Gendered Biographies'), ('fem_per', 'percentage of female Biographies')]:
    ssl = sitelinks[sitelinks['wikitype']=='pedia'].sort([sort_term])
    planstep = len(ssl)/float(splitpoints)

    
    for per_type, std_ylim, title_text in [('fem_per', 0.8, 'Female Composition'), ('nonbin_per',0.005, 'Non-binary Gender Percentage')]:

        fig, axes = plt.subplots(nrows=splitpoints, ncols=1, figsize=(12,20))
        plt.subplots_adjust(hspace = 0.8 )
        for splitpoint in range(0,splitpoints):
            begin = int(math.ceil(splitpoint * planstep))
            end = int(math.floor((splitpoint+1) * planstep))

            
            bios_list = ssl.iloc[begin:end]['gendered_total']
            minbio = int(min(bios_list))
            maxbio = int(max(bios_list))
            ratios_list = ssl.iloc[begin:end][per_type]
            maxratio = max(ratios_list)
            minratio = min(ratios_list)

            bios_size = bios_list.apply(lambda x: math.log(x)/math.log(maxbio)) 

            my_colors = [(x, x/2, 0.75) for x in bios_size]
            


            ssl.iloc[begin:end][per_type].plot(ax=axes[splitpoint], kind='bar', color=my_colors)


            axes[splitpoint].set_title(" %s with %s to %s gendered biographies" % (title_text, minbio, maxbio))
            axes[splitpoint].set_ylim((minratio*0.9,maxratio*1.1))
            axes[splitpoint].grid(False)
            axes[splitpoint].yaxis.grid(True, linestyle="--", linewidth=0.3)
            axes[splitpoint].lines[0].set_visible(False)
            axes[splitpoint].yaxis.set_ticks_position('none')
            axes[splitpoint].xaxis.set_ticks_position('none')
            wikilabels = axes[splitpoint].get_xticklabels()
            wikinames = map(lambda x: x.get_text().split('wiki')[0], wikilabels)
            fullnames = map(lookup_lang, wikinames)
            axes[splitpoint].set_xticklabels(fullnames)
        fig.suptitle("""%s of all Wikipedia Languages\n
        ordered by %s. Color is locally relative Wiki Size""" % (title_text, sort_term_text), fontsize=24)    
        plt.show

# %%
sitelinks[sitelinks['wikitype']=='pedia'].sort(['gendered_total'])['gendered_total'].plot(figsize=(36,6),kind='bar', logy=True)

# %%
#find the correct cut off so that we are only inspecting the top TOP wikis by gendered biographies
TOP = 50
scatdata = None
for vartotal in range(0, int(max(sitelinks['gendered_total']))):
    scatdata = sitelinks[(sitelinks['wikitype']=='pedia') & (sitelinks['gendered_total'] > vartotal)]
    if len(scatdata) > TOP:
        continue
    else:
        print(vartotal)
        break
        
nonbintot = None
for vartotal in range(0, int(max(sitelinks['gendered_total']))):
    nonbintot= sitelinks[(sitelinks['wikitype']=='pedia') & (sitelinks['nonbin_total'] > vartotal)]
    if len(nonbintot) > TOP:
        continue
    else:
        print(vartotal)
        break
# Out:
# 137775
# 20

# %%
scatdata.head()
# Out:
#          nan  transgender female  intersex  fa'afafine  transgender male  \
# dewiki    83                  24         0           1                10
# enwiki  2965                 105        17           1                26
# eswiki   497                  30         3           1                 6
# frwiki   313                  33         3           0                 5
# itwiki    82                  24         2           1                 4
#
#         female animal  male animal  woman  genderqueer  female     male  \
# dewiki              0            0      0            3   81249   462244
# enwiki              0            0      0           12  186361  1015978
# eswiki              0            0      0            1   37889   199525
# frwiki              0            0      0            3   62842   350252
# itwiki              0            1      0            0   38753   230264
#
#         kathoey  human_total  gendered_total  gendered_per  nonbin_total  \
# dewiki        1       543615          543532      0.999847            39
# enwiki        1      1205466         1202501      0.997540           162
# eswiki        0       237952          237455      0.997911            41
# frwiki        0       413451          413138      0.999243            44
# itwiki        0       269131          269049      0.999695            32
#
#        wikitype wikilang   fem_per  nonbin_per
# dewiki    pedia       de  0.149483    0.000072
# enwiki    pedia       en  0.154978    0.000135
# eswiki    pedia       es  0.159563    0.000173
# frwiki    pedia       fr  0.152109    0.000107
# itwiki    pedia       it  0.144037    0.000119

# %%
scatdata[['gendered_total','fem_per']].to_csv('Magnus Gender analysis/lang_scat.csv')

# %%
sp =scatdata.plot(kind='scatter', x='gendered_total', y='fem_per', logx=True, figsize=(16,10), c='#e3ae3d')
codes = map(lambda x: str(x).split('wiki')[0], scatdata.index)
fullnames = map(lookup_lang,codes)

sp.set_xlim(min(scatdata['gendered_total']) * 0.85, max(scatdata['gendered_total']) *1.15)
sp.set_ylim(min(scatdata['fem_per']) * 0.95, max(scatdata['fem_per']) *1.05)

sp.yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, y: '{:.0%}'.format(x )))
sp.xaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, y: '{:,.0f}'.format(x )))


sp.set_title('Female ratio of biographies, by Wikipedia Language \nTop {} Wikipedias by Biography count\n'.format(TOP), fontsize=24)
sp.set_xlabel('Number of gendered Biographies, log scale', fontsize=18)
sp.set_ylabel('Female ratio of Biographies',  fontsize=18)

(x1, x2), (y1, y2) = sp.get_xlim(), sp.get_ylim()
middle = (x2-x1)/2.0 , (y2-y1)/2.0

f = matplotlib.font_manager.FontProperties()
font1 = f.copy()

#font1.set_weight('light')

for label, x, y in zip(fullnames, scatdata['gendered_total'], scatdata['fem_per']):
    plt.annotate(
        label,
        xy = (x, y), 
        xytext = (3,-3) if label in ['Latvian','Polish','Dutch','Slovak','Hungarian'] else (0,2),
        textcoords = 'offset points', ha = 'center', va = 'bottom',
        fontsize=8, fontproperties=font1)

# %%
np = scatdata.plot(kind='scatter', x='gendered_total', y='nonbin_per', logx=True, figsize=(16,10), c='#f34141')
codes = map(lambda x: str(x).split('wiki')[0], scatdata.index)
fullnames = map(lookup_lang,codes)

np.yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, y: '{:.2%}'.format(x )))
np.xaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, y: '{:,.0f}'.format(x )))

np.set_xlim(min(scatdata['gendered_total']) * 0.85, max(scatdata['gendered_total']) *1.15)
np.set_ylim(min(scatdata['nonbin_per']) * 0.95, max(scatdata['nonbin_per']) *1.05)
np.set_title('Nonbinary ratio of biographies, by Wikipedia Language \nTop {} Wikipedias by Biography count\n'.format(TOP), fontsize=24)
np.set_xlabel('Number of gendered Biographies, log scale', fontsize=18)
np.set_ylabel('Nonbinary ratio of Biographies',  fontsize=18)

f = matplotlib.font_manager.FontProperties()
font1 = f.copy()

#font1.set_weight('light')

for label, x, y in zip(fullnames, scatdata['gendered_total'], scatdata['nonbin_per']):
    plt.annotate(
        label,
        xy = (x, y), 
        xytext = (5,-5) if label in ['Czech'] else (0,2),
        textcoords = 'offset points', ha = 'center', va = 'bottom',
        fontsize=8, fontproperties=font1)
    

    
plt.show()


'''
np = nonbintot.plot(kind='scatter', x='nonbin_total', y='nonbin_per', logx=True, figsize=(16,10))
codes = map(lambda x: str(x).split('wiki')[0], nonbintot.index)
fullnames = map(lookup_lang,codes)



np.set_xlim(min(nonbintot['nonbin_total']) * 0.85, max(nonbintot['nonbin_total']) *1.15)
np.set_ylim(min(nonbintot['nonbin_per']) * 0.95, max(nonbintot['nonbin_per']) *1.05)
np.set_title('Nonbinary percentage of biographies, by Wikipedia Language \nTop 50 Wikipedias by Biography count\n', fontsize=24)
np.set_xlabel('Number of gendered Biographies, log scale', fontsize=18)
np.set_ylabel('Non binary percentage of Biographies',  fontsize=18)


for label, x, y in zip(fullnames, nonbintot['nonbin_total'], nonbintot['nonbin_per']):
    plt.annotate(
        label,
        xy = (x, y), xytext = (0,2),
        textcoords = 'offset points', ha = 'center', va = 'bottom',
        fontsize=8)
plt.show()
'''
# Out:
# "\nnp = nonbintot.plot(kind='scatter', x='nonbin_total', y='nonbin_per', logx=True, figsize=(16,10))\ncodes = map(lambda x: str(x).split('wiki')[0], nonbintot.index)\nfullnames = map(lookup_lang,codes)\n\n\n\nnp.set_xlim(min(nonbintot['nonbin_total']) * 0.85, max(nonbintot['nonbin_total']) *1.15)\nnp.set_ylim(min(nonbintot['nonbin_per']) * 0.95, max(nonbintot['nonbin_per']) *1.05)\nnp.set_title('Nonbinary percentage of biographies, by Wikipedia Language \nTop 50 Wikipedias by Biography count\n', fontsize=24)\nnp.set_xlabel('Number of gendered Biographies, log scale', fontsize=18)\nnp.set_ylabel('Non binary percentage of Biographies',  fontsize=18)\n\n\nfor label, x, y in zip(fullnames, nonbintot['nonbin_total'], nonbintot['nonbin_per']):\n    plt.annotate(\n        label,\n        xy = (x, y), xytext = (0,2),\n        textcoords = 'offset points', ha = 'center', va = 'bottom',\n        fontsize=8)\nplt.show()\n"

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(sitelinks[(sitelinks['wikitype']=='pedia')& (sitelinks['gendered_total']>1000)][['fem_per','gendered_total']])
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
int(float(-6.2590421446e-09))
# Out:
# 0

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
logtrans = pandas.DataFrame()
logtrans['nonbin_per'] = sitelinks[(sitelinks['wikitype']=='pedia') & (sitelinks['nonbin_per'] != 0)]['nonbin_per'].apply(math.log)
logtrans['gen_tot'] = sitelinks[(sitelinks['wikitype']=='pedia')& (sitelinks['nonbin_per'] != 0)]['gendered_total'].apply(math.log)
pca.fit(logtrans)
# Out:
# PCA(copy=True, n_components=1, whiten=False)

# %%
print pca.components_, pca.explained_variance_ratio_
# Out:
# [[-0.47986084  0.87734461]] [ 0.89353149]

# %%
sitelinks[['gendered_total','female','male']].corr()
# Out:
#                 gendered_total    female      male
# gendered_total        1.000000  0.996209  0.999871
# female                0.996209  1.000000  0.994684
# male                  0.999871  0.994684  1.000000
