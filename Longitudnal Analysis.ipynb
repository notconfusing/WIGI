# %%
# %run longitudinal.py

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
sitedata['enwiki']
# Out:
#                  date     male  female
# date
# 2015-08-09 2015-08-09  1074073  201309
# 2015-08-23 2015-08-23  1074954  201560
# 2015-08-21 2015-08-21  1074954  201560
# 2015-08-03 2015-08-03  1073280  201101
# 2015-10-13 2015-10-13  1097981  207193
# 2015-12-07 2015-12-07   264022   49304
# 2015-12-04 2015-12-04  1104819  208983
# 2015-12-21 2015-12-21  1109493  210352
# 2015-09-13 2015-09-13  1079791  202737
# 2015-10-26 2015-10-26  1101177  207858
# 2015-11-23 2015-11-23  1104342  208826
# 2015-08-12 2015-08-12  1074385  201408
# 2015-08-16 2015-08-16  1074385  201408
# 2015-11-09 2015-11-09  1103415  208538
# 2015-11-02 2015-11-02  1102712  208271
# 2015-10-19 2015-10-19  1097981  207193
# 2015-11-21 2015-11-21  1103982  208716
# 2015-11-22 2015-11-22  1103982  208716
# 2015-07-28 2015-07-28  1073280  201101
# 2015-12-14 2015-12-14   264022   49304
# 2015-09-06 2015-09-06  1076148  202005
# 2015-09-27 2015-09-27  1088176  204530
# 2015-09-20 2015-09-20  1085055  203821

# %%
1 + 1

# %%
sitedata['enwiki'].plot();sitedata['dewiki'].plot

# %%
print(sites)
# Out:
# ['fawiki', 'ugwiki', 'kvwiki', 'kbdwiki', 'orwikisource', 'nrmwiki', 'csbwiki', 'hakwiki', 'kshwiki', 'elwikiquote', 'nawiki', 'tumwiki', 'pswiki', 'tewiki', 'krcwiki', 'idwikibooks', 'lawikisource', 'guwikisource', 'gdwiki', 'nlwiki', 'cvwiki', 'mrjwiki', 'diqwiki', 'nowiki', 'cewiki', 'fowiki', 'mnwiki', 'iewiki', 'cswikisource', 'enwikisource', 'jawikiquote', 'plwikiquote', 'glwikiquote', 'ptwiki', 'hywikiquote', 'lbewiki', 'twwiki', 'papwiki', 'yowiki', 'hawwiki', 'pagwiki', 'yiwiki', 'rmwiki', 'idwiki', 'udmwiki', 'mkwikisource', 'vepwiki', 'tywiki', 'knwiki', 'guwiki', 'scnwiki', 'srwikisource', 'tlwiki', 'kkwiki', 'frwikisource', 'ukwikisource', 'eswiki', 'cywikiquote', 'arwikinews', 'plwiki', 'astwiki', 'iswikiquote', 'dawiki', 'arwikiquote', 'cswiki', 'itwikiquote', 'mywiki', 'itwiki', 'hrwiki', 'snwiki', 'iswikibooks', 'oswiki', 'brwikisource', 'nowikisource', 'shwiki', 'elwiki', 'emlwiki', 'azwiki', 'pamwiki', 'idwikisource', 'stqwiki', 'enwiki', 'zhwikisource', 'bswikisou
# ...

# %%
male[['enwiki', 'frwiki', 'dewiki']]
# Out:
#              enwiki  frwiki  dewiki
# date
# 2015-08-09  1074073  374966  489448
# 2015-08-23  1074954  375931  491300
# 2015-08-21  1074954  375931  491300
# 2015-08-03  1073280  374387  488575
# 2015-10-13  1097981  380882  496679
# 2015-12-07   264022   93761  120770
# 2015-12-04  1104819  384197  499906
# 2015-12-21  1109493  385565  500956
# 2015-09-13  1079791  377236  492544
# 2015-10-26  1101177  381979  497480
# 2015-11-23  1104342  383710  499424
# 2015-08-12  1074385  375477  490834
# 2015-08-16  1074385  375477  490834
# 2015-11-09  1103415  382966  498432
# 2015-11-02  1102712  382334  497982
# 2015-10-19  1097981  380882  496679
# 2015-11-21  1103982  383342  498870
# 2015-11-22  1103982  383342  498870
# 2015-07-28  1073280  374387  488575
# 2015-12-14   264022   93761  120770
# 2015-09-06  1076148  376644  492270
# 2015-09-27  1088176  379167  493422
# 2015-09-20  1085055  378238  492968

# %%
male[['enwiki', 'frwiki', 'dewiki', 'eswiki']].plot()

# %%
female[['enwiki', 'frwiki', 'dewiki', 'eswiki']].plot()

# %%
female[['hiwiki', 'urwiki']].plot()

# %%
# 4 Dravidian Languages in India: Telugu, Tamil, Malyalam, Kannada
female[['tewiki', 'tawiki', 'mlwiki', 'knwiki']].plot()
