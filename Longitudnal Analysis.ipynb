# %%
# %run longitudinal.py
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/hargup/WIGI/longitudinal.py in <module>()
#      78     female[site] = sitedata[site]['female']
#      79
# ---> 80 male.index = male['date']
#      81 female.index = female['date']
#      82 male['date'] = pd.to_datetime(data.keys())
#
# /home/hargup/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1912             return self._getitem_multilevel(key)
#    1913         else:
# -> 1914             return self._getitem_column(key)
#    1915
#    1916     def _getitem_column(self, key):
#
# /home/hargup/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1919         # get column
#    1920         if self.columns.is_unique:
# -> 1921             return self._get_item_cache(key)
#    1922
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
#x = pd.Series(sitedata['enwiki'])
sitedata['enwiki'].index = sitedata['enwiki'].date

# %%
sitedata['enwiki'].plot();sitedata['dewiki'].plot

# %%
sitedata['enwiki']['male']

for site in sites:
    male[site] = sitedata[site]['male']
    female[site] = sitedata[site]['female']

# %%
male[['enwiki', 'frwiki', 'dewiki']]
# Out:
#              enwiki  frwiki  dewiki
# date
# 2015-08-12  1074385  375477  490834
# 2015-12-04  1104819  384197  499906
# 2015-10-13  1097981  380882  496679
# 2015-07-28  1073280  374387  488575
# 2015-08-23  1074954  375931  491300
# 2015-08-21  1074954  375931  491300
# 2015-12-07   264022   93761  120770
# 2015-08-09  1074073  374966  489448
# 2015-11-09  1103415  382966  498432
# 2015-08-03  1073280  374387  488575
# 2015-11-23  1104342  383710  499424
# 2015-09-06  1076148  376644  492270
# 2015-09-13  1079791  377236  492544
# 2015-10-19  1097981  380882  496679
# 2015-11-02  1102712  382334  497982
# 2015-10-26  1101177  381979  497480
# 2015-09-27  1088176  379167  493422
# 2015-09-20  1085055  378238  492968
# 2015-11-21  1103982  383342  498870
# 2015-11-22  1103982  383342  498870
# 2015-08-16  1074385  375477  490834

# %%
male[['enwiki', 'frwiki', 'dewiki']].plot()

# %%
female[['enwiki', 'frwiki', 'dewiki']].plot()

# %%
female[['hiwiki', 'urwiki']].plot()
